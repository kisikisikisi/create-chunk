# %% [markdown]
# # CloudVision

# %%
# -*- coding: utf_8 -*-
import io
import os
import json
import glob

from pprint import pprint

# Google Cloud client libraryのインポート
from google.cloud import vision
from google.cloud.vision import types

from google.protobuf.json_format import MessageToJson

def annotate(basename):
    # 画像のファイルパス
    file_name = os.path.join(
        os.path.dirname(__file__),
        '/{}'.format(basename))

    # 画像のロード
    with io.open(file_name, 'rb') as image_file:
        content = image_file.read()

    image = types.Image(content=content)

    # 日本語のヒントを与える
    image_context = types.ImageContext(language_hints=['ja'])

    response = client.text_detection(image=image,image_context=image_context)

    # JSON ファイル書き出し
    serialized = MessageToJson(response)
    data = json.loads(serialized)

    f = open('results/{}.json'.format(os.path.splitext(basename)[0]), 'w')
    f.write(json.dumps(data,ensure_ascii=False))
    f.close()

# クライアント初期化
client = vision.ImageAnnotatorClient()

# resources フォルダ内の画像をすべてAPIに投げる
paths = glob.glob("/*.png")

for path in paths:
    annotate(os.path.basename(path))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-3c63a44fa6cb> in <module>()
#       8
#       9 # Google Cloud client libraryのインポート
# ---> 10 from google.cloud import vision
#      11 from google.cloud.vision import types
#      12
#
# ImportError: No module named 'google.cloud'

# %% [markdown]
# # Create thumbnail data

# %%
import requests
import os
import json
from time import sleep

json_open = open('history.json', 'r', encoding='utf8')
json_load = json.load(json_open)

for i in range(len(json_load)):
    url = "https://s.wordpress.com/mshots/v1/" + str(json_load[i]["url"])
    # Responseオブジェクトの生成
    res = requests.get(url)

    print(url)
    # レスポンスの中身（最初の200文字）
    print(res.headers['Content-Type'],i)
    fn = ""
    if "jpeg" in res.headers['Content-Type']:
        fn = ".jpeg"
    else:
        fn = ".gif"
    sleep(20)
    with open("C:\\Users\\bi17030\\Documents\\Research\\thumbnail_data\\" + 
              "image" + str(i) + fn, 'wb') as f:
        f.write(res.content)

# %% [markdown]
# # Janome

# %%
print(str(bytes("プリン", 'utf-8'))[2:-1])
# Out:
# \xe3\x83\x97\xe3\x83\xaa\xe3\x83\xb3

# %%
import json
import binascii
from janome.tokenizer import Tokenizer
import six

invalid=[" ", "　", ":", ".", ",", ")"]

tokenizer = Tokenizer()
json_open = open('history.json', 'r', encoding='utf8')
json_load = json.load(json_open)

for i in range(len(json_load)):
    print(json_load[i]["title"])
    with open("./idata/"+str(json_load[i]["id"])+"t.lisp",mode="w", encoding='utf8') as f:
        f.write("(setf *image-struct* '" + '(("' + str(json_load[i]["id"]) + 't" ' + '10 10 10 10 BLUE)' + '\n')
        sentence = str(json_load[i]["title"])
        x = 5
        for token in tokenizer.tokenize(sentence):
            s = str(token.surface)
            if not s in invalid:
                sx = str(x)+' '
                text = repr((bytes(s, 'utf-8')))[2:-1]
                text = text.replace(chr(92),'')
                #f.write('("' + text + '" ' + sx +'400 10 '+str(400-int(sx))+' GREEN)\n')#hei,wid,x,y
                f.write('("' + text + '" ' + '5 5 '+sx+'400 GREEN)\n')#hei,wid,x,y
                x += 15
        f.write("))")
# Out:
# History export - Chrome ウェブストア
# History export - Chrome ウェブストア
# Chrome ウェブストア - history export
# json-xls.com - json/xml to excel/CSV/html online converter and viewer
# Export History/Bookmarks to JSON/CSV*/XLS* - Chrome ウェブストア
# Chrome ウェブストア - 拡張機能
# Chrome ウェブストア - 拡張機能
# Chromeストア - Google 検索
# chrome 履歴 保存場所 windows10 - Google 検索
# Webブラウザの履歴ファイルの格納場所とビューア - setodaNote
# Google Chrome のキャッシュの場所を確認する
# Chrome　履歴　エクスポート - Google 検索
# Google Chrome の履歴を csv で出力する - walkingmask’s development log
# Google Chromeの閲覧履歴をCSV形式で保存する方法｜MENTA
# Google Chromeの閲覧履歴をCSV形式で保存する方法｜もりやまよしあき（森山義章）｜note
# Chromeの閲覧履歴の保存について - Google Chrome Community
# テイクアウト Chrome - Google 検索
# データのダウンロード - Google アカウント ヘルプ
# 高度な保護機能プログラム
# Google アカウント
# セキュリティ診断
# takeout-20200420T050757Z-001.zip - Google ドライブ
# Google - マイ アクティビティ
# アクティビティ管理
# Google - マイ アクティビティ
# Chromeの閲覧履歴を検索したい！日付指定で検索する方法【アドオン不要】 | スマホアプリやiPhone/Androidスマホなどの各種デバイスの使い方・最新情報を紹介するメディアです。
# chrome 履歴　テイクアウト - Google 検索
# Chrome の閲覧履歴を削除する - パソコン - Google Chrome ヘルプ
# chrome アーカイブ - Google 検索
# データのダウンロード - Google アカウント ヘルプ
# Google アカウント データの概要の確認 - Google アカウント ヘルプ
# Chrome 履歴 エクスポート テイクアウト - Google 検索
# Chrome 履歴 エクスポート Windows - Google 検索
# Google Chromeの閲覧履歴をCSV形式で保存する方法 | 義経ITクラブ
# Google データ エクスポート
# Google アカウント
# Google アカウント
# エクスポートの管理
# chrome 履歴 エクスポート - Google 検索
# Google Chromeの閲覧履歴をエクスポートする - Qiita
# Google Chromeの閲覧履歴をコピーする方法｜もりやまよしあき（森山義章）｜note
# テイクアウト Chrome　できない - Google 検索
# テイクアウト Chrome - Google 検索
# takeout-20200420T070552Z-001.zip - Google ドライブ
# エクスポートの管理
# ログイン - Google アカウント
# kok - Google 検索
# エクスポートの管理
# ログイン - Google アカウント
# ログイン - Google アカウント
# ログイン - Google アカウント
# テイクアウト - Google 検索
# dfagasd - Google 検索
# Qiita
# document.header - Google 検索
# fdas - Google 検索
# Qiita - Google 検索
# ウィキペディア - Google 検索
# Wikipedia
# 楽天 - Google 検索
# 【楽天市場】Shopping is Entertainment! ： インターネット最大級の通信販売、通販オンラインショッピングコミュニティ
# Qiita - Google 検索
# Qiita週間ストック数ランキング【自動更新】 - Qiita
# fdas - Google 検索
# 競技プログラマーがWeb開発者の卵になるまでの軌跡 - Qiita
# jioj - Google 検索
# joij - Google 検索
# 楽天 - Google 検索
# 楽天証券 | ネット証券（株・FX・投資信託･確定拠出年金･NISA）
# jiojo - Google 検索
# 英和辞典・和英辞典 - Weblio辞書
# goo辞書 - 国語・英語・四字熟語のオンライン辞書
# [JavaScript] JSだけでスクリーンショットを撮ってダウンロードもする方法 - Qiita
# javascript スクリーンショット - Google 検索
# qiita - Google 検索
# javascript スクリーンショット - Google 検索
# Yv9q0kJ+ofwAAAAASUVORK5CYII= (1759×3214)
# 【javascript】スクリーンショットをjpeg保存できるスクリプトコマンド（未完成・デベロッパー用） | ツクールフォーラム
# くりーむわーかー : Webシステムのスクリーンショットをjavascriptとか使ってとる
# JavaScript 向けブラウザスクリーンショットライブラリ html2canvas で画面の一部分のみのスクリーンショットをとってみました | Developers.IO
# qiitak - Google 検索
# qiitakop - Google 検索
# qiita - Google 検索
# qiita - Google 検索
# ERROR Error: Uncaught (in promise): [object Event] · Issue #1593 · niklasvh/html2canvas · GitHub
# uncaught (in promise) html2canvas - Google 検索
# javascript - html2canvas Uncaught (in promise) undefined - Stack Overflow
# isTrusted: true type: "error" target: null currentTarget: null eventPhase: 0 bubbles: false cancelable: false defaultPrevented: false composed: false timeStamp: 1656.6100000054576 srcElement: null returnValue: true cancelBubble: false - Google 検索
# jjioj - Google 検索
# JCSS2019_P1-3.pdf
# 認知科学会第36回大会を開催しました | Mirroring with Cognitive Modeling
# 認知化学会　Thanakit - Google 検索
# fsdadfasdfasdf - Google 検索
# fsda - Google 検索
# Chrome 拡張機能のマニフェストファイルの書き方 - Qiita
# Chrome拡張 mathces - Google 検索
# ｄｓｄ - Google 検索
# ｄｓｆｒ - Google 検索
# ｆじょだｓｆ - Google 検索
# 無料画像を探してダウンロード - Pixabay
# 1.700万点以上の高品質なフリー画像素材 - Pixabay
# フリー画像 - Google 検索
# ｈｄｒｈ - Google 検索
# 【あつ森】4月の魚一覧 | 値段と出現時間・場所【あつまれどうぶつの森】 - GameWith
# 【あつ森】カミツキガメの値段と釣り方・出現時間【あつまれどうぶつの森】 - GameWith
# 【あつ森】シーラカンスの値段と釣り方・出現時間【あつまれどうぶつの森】 - GameWith
# シーラカンスあつ森 - Google 検索
# webサイト 作り方 - Google 検索
# kirohi - Google 検索
# 【2020年ホームページの作り方総まとめ】ホームページ自作方法を解説 | WEBST8
# jmkmk - Google 検索
# Javascript - Google 検索
# huhihｄｆｓ - Google 検索
# huhih - Google 検索
# HTML,CSS　カラーコード一覧表　｜　背景色や文字色の設定
# css 色 - Google 検索
# Chromeのブラウザの背景色を白黒反転させる方法を解説！ハイコントラスト/タブの色/変える | Aprico
# Chrome拡張 背景の色 - Google 検索
# 圧縮 英語 - Google 検索
# element.insertAdjacentHTML - Web API | MDN
# Html2Canvasでwebページのスクリーンショットを取ろう(1)「ライブラリの紹介」
# Python　しゃくとり法 - Google 検索
# Python　ランレングス圧縮 - Google 検索
# Python　優先度付きキュー - Google 検索
# 重なる 英語 - Google 検索
# テスト - Google 検索
# insertadjacenthtml - Google 検索
# テストテスト - Google 検索
# ああああ - Google 検索
# テスト - Google 検索
# test - Google 検索
# sample - Google 検索
# test - Google 検索
# fedag - Google 検索
# Javascript スクリーンショット　html2canvas - Google 検索
# Javascript スクリーンショット - Google 検索
# javascript - ボタンクリックしたら、HTMLの指定タグ(id)範囲のみ画面キャプチャしたい - スタック・オーバーフロー
# JavascriptでWebページのスクリーンショット画像を取得
# Javascript サムネ　取得 - Google 検索
# リンク先のサムネイル画像を表示させる（画像保存無し） - Qiita
# Javascript サムネイル画像 - Google 検索
# サムネイルが右側に並んだ画像リストのCSSとJSをじっくりコーディング（JS編） | oshin.tokyo
# サムネイルが右側に並んだ画像リストのCSSとJSをじっくりコーディング（JS編） | oshin.tokyo
# HTML サムネイル画像 - Google 検索
# CSSだけでサムネイル画像を作る。全部のパターンをご紹介します！ | ホームページ作成や運用支援する｜ホームページTips｜静岡県浜松市を拠点にホームページ制作を行うアドレック事業部
# ウェブサイトのサムネイル画像を表示するHTMLタグの説明
# javascript スクリーンショット - Google 検索
# スクリーンショットを撮るのはChromeがいちばん?! | Developers.IO
# javascript - Google 検索
# スクリーンショット　Javascript - Google 検索
# googlechrome 拡張機能　スクリーンショット - Google 検索
# 【知ってた？ Chrome裏技】縦に長いWebページ全体のスクリーンショットを撮る方法（拡張機能も不要！） | できるネット
# googlechrome 拡張機能 - Google 検索
# リサーチプロポーザル - Google 検索
# てｓｔ - Google 検索
# gasdg - Google 検索
# gasdg - Google 検索
# fad - Google 検索
# fds - Google 検索
# qiita - Google 検索
# 【楽天市場】靴 メンズの通販
# 【楽天市場】thinkpad（パソコン・周辺機器）の通販
# 【楽天市場】thinkpadの通販
# 楽天 - Google 検索
# 【楽天市場】ズボン・パンツ（メンズファッション）の通販
# 【楽天市場】【送料無料】【2枚目半額クーポン】2/12(水)18時迄 チノパン メンズ カラーパンツ スリムパンツ ボトムス ゴルフパンツ スリム ストレッチ スキニーパンツ アンクルパンツ ジーパン デニム ジーンズ テーパードパンツ ズボン 黒 黒スキニー メンズファッション パンツ：improves
# Getting Started Tutorial - Google Chrome
# Load unpacked - Google 検索
# Data Collection Sub-system.rar - Google ドライブ

# %%
from janome.tokenizer import Tokenizer

tokenizer = Tokenizer()

sentenses = [
    "History export - Chrome ウェブストア",
    "wajijpfda"
]

for sentence in sentenses:
    print("=============================================")
    print(sentence)

    for token in tokenizer.tokenize(sentence):
        print("    " + str(token.surface))
# Out:
# =============================================
# History export - Chrome ウェブストア
#     History
#
#     export
#
#     -
#
#     Chrome
#
#     ウェブストア
# =============================================
# さあご一緒に！「TRUE 1 が TRUE！ TRUE 0 が FALSE！」
#     さあ
#     ご
#     一緒
#     に
#     ！
#     「
#     TRUE
#
#     1
#
#     が
#
#     TRUE
#     ！
#
#     TRUE
#
#     0
#
#     が
#
#     FALSE
#     ！
#     」
