# %% [markdown]
# (sdp 781 :creation-time 12313 :reference-list())
# (sdp 781-Chrome :creation-time 12313 :reference-list())
# (sdp l-headgear :creation-time 1580985649 :reference-list (1580985649))
# (sdp 781-time2 :creation-time 12313 :reference-list())

# %%
with open('img-dm.lisp', mode="r", encoding='utf8') as f:
    for i,j in enumerate(f):
        print(i,j)
print(i)
leng = str(i)
# Out:
# 0 (add-dm-fct '((679 isa image-data text "679" type image)
#
# 1 (864 isa image-data text "864" type image)
#
# 2 (866 isa image-data text "866" type image)
#
# 3 (867 isa image-data text "867" type image)
#
# 4 (868 isa image-data text "868" type image)
#
# 5 (869 isa image-data text "869" type image)
#
# 6 (870 isa image-data text "870" type image)
#
# 7 (871 isa image-data text "871" type image)
#
# 8 (872 isa image-data text "872" type image)
#
# 9 (873 isa image-data text "873" type image)
#
# 10 (l-Chrome isa label-data text "Chrome")
#
# 11 (679-Chrome isa inc-label idata 679 label l-Chrome)
#
# 12 (l-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2 isa label-data text "xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2")
#
# 13 (679-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2 isa inc-label idata 679 label l-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2)
#
# 14 (l-- isa label-data text "-")
#
# 15 (679-- isa inc-label idata 679 label l--)
#
# 16 (l-xe6x8bxa1xe5xbcxb5 isa label-data text "xe6x8bxa1xe5xbcxb5")
#
# 17 (679-xe6x8bxa1xe5xbcxb5 isa inc-label idata 679 label l-xe6x8bxa1xe5xbcxb5)
#
# 18 (l-xe6xa9x9fxe8x83xbd isa label-data text "xe6xa9x9fxe8x83xbd")
#
# 19 (679-xe6xa9x9fxe8x83xbd isa inc-label idata 679 label l-xe6xa9x9fxe8x83xbd)
#
# 20 (l-chrome isa label-data text "chrome")
#
# 21 (864-chrome isa inc-label idata 864 label l-chrome)
#
# 22 (l-xe5xb1xa5xe6xadxb4 isa label-data text "xe5xb1xa5xe6xadxb4")
#
# 23 (864-xe5xb1xa5xe6xadxb4 isa inc-label idata 864 label l-xe5xb1xa5xe6xadxb4)
#
# 24 (l-xe4xbfx9dxe5xadx98 isa label-data text "xe4xbfx9dxe5xadx98")
#
# 25 (864-xe4xbfx9dxe5xadx98 isa inc-label idata 864 label l-xe4xbfx9dxe5xadx98)
#
# 26 (l-xe5xa0xb4xe6x89x80 isa label-data text "xe5xa0xb4xe6x89x80")
#
# 27 (864-xe5xa0xb4xe6x89x80 isa inc-label idata 864 label l-xe5xa0xb4xe6x89x80)
#
# 28 (l-windows isa label-data text "windows")
#
# 29 (864-windows isa inc-label idata 864 label l-windows)
#
# 30 (l-10 isa label-data text "10")
#
# 31 (864-10 isa inc-label idata 864 label l-10)
#
# 32 (l-- isa label-data text "-")
#
# 33 (864-- isa inc-label idata 864 label l--)
#
# 34 (l-Google isa label-data text "Google")
#
# 35 (864-Google isa inc-label idata 864 label l-Google)
#
# 36 (l-xe6xa4x9cxe7xb4xa2 isa label-data text "xe6xa4x9cxe7xb4xa2")
#
# 37 (864-xe6xa4x9cxe7xb4xa2 isa inc-label idata 864 label l-xe6xa4x9cxe7xb4xa2)
#
# 38 (l-Web isa label-data text "Web")
#
# 39 (866-Web isa inc-label idata 866 label l-Web)
#
# 40 (l-xe3x83x96xe3x83xa9xe3x82xa6xe3x82xb6 isa label-data text "xe3x83x96xe3x83xa9xe3x82xa6xe3x82xb6")
#
# 41 (866-xe3x83x96xe3x83xa9xe3x82xa6xe3x82xb6 isa inc-label idata 866 label l-xe3x83x96xe3x83xa9xe3x82xa6xe3x82xb6)
#
# 42 (l-xe3x81xae isa label-data text "xe3x81xae")
#
# 43 (866-xe3x81xae isa inc-label idata 866 label l-xe3x81xae)
#
# 44 (l-xe5xb1xa5xe6xadxb4 isa label-data text "xe5xb1xa5xe6xadxb4")
#
# 45 (866-xe5xb1xa5xe6xadxb4 isa inc-label idata 866 label l-xe5xb1xa5xe6xadxb4)
#
# 46 (l-xe3x83x95xe3x82xa1xe3x82xa4xe3x83xab isa label-data text "xe3x83x95xe3x82xa1xe3x82xa4xe3x83xab")
#
# 47 (866-xe3x83x95xe3x82xa1xe3x82xa4xe3x83xab isa inc-label idata 866 label l-xe3x83x95xe3x82xa1xe3x82xa4xe3x83xab)
#
# 48 (l-xe3x81xae isa label-data text "xe3x81xae")
#
# 49 (866-xe3x81xae isa inc-label idata 866 label l-xe3x81xae)
#
# 50 (l-xe6xa0xbcxe7xb4x8d isa label-data text "xe6xa0xbcxe7xb4x8d")
#
# 51 (866-xe6xa0xbcxe7xb4x8d isa inc-label idata 866 label l-xe6xa0xbcxe7xb4x8d)
#
# 52 (l-xe5xa0xb4xe6x89x80 isa label-data text "xe5xa0xb4xe6x89x80")
#
# 53 (866-xe5xa0xb4xe6x89x80 isa inc-label idata 866 label l-xe5xa0xb4xe6x89x80)
#
# 54 (l-xe3x81xa8 isa label-data text "xe3x81xa8")
#
# 55 (866-xe3x81xa8 isa inc-label idata 866 label l-xe3x81xa8)
#
# 56 (l-xe3x83x93xe3x83xa5xe3x83xbcxe3x82xa2 isa label-data text "xe3x83x93xe3x83xa5xe3x83xbcxe3x82xa2")
#
# 57 (866-xe3x83x93xe3x83xa5xe3x83xbcxe3x82xa2 isa inc-label idata 866 label l-xe3x83x93xe3x83xa5xe3x83xbcxe3x82xa2)
#
# 58 (l-- isa label-data text "-")
#
# 59 (866-- isa inc-label idata 866 label l--)
#
# 60 (l-setodaNote isa label-data text "setodaNote")
#
# 61 (866-setodaNote isa inc-label idata 866 label l-setodaNote)
#
# 62 (l-Chrome isa label-data text "Chrome")
#
# 63 (867-Chrome isa inc-label idata 867 label l-Chrome)
#
# 64 (l-xe3x82xb9xe3x83x88xe3x82xa2 isa label-data text "xe3x82xb9xe3x83x88xe3x82xa2")
#
# 65 (867-xe3x82xb9xe3x83x88xe3x82xa2 isa inc-label idata 867 label l-xe3x82xb9xe3x83x88xe3x82xa2)
#
# 66 (l-- isa label-data text "-")
#
# 67 (867-- isa inc-label idata 867 label l--)
#
# 68 (l-Google isa label-data text "Google")
#
# 69 (867-Google isa inc-label idata 867 label l-Google)
#
# 70 (l-xe6xa4x9cxe7xb4xa2 isa label-data text "xe6xa4x9cxe7xb4xa2")
#
# 71 (867-xe6xa4x9cxe7xb4xa2 isa inc-label idata 867 label l-xe6xa4x9cxe7xb4xa2)
#
# 72 (l-Chrome isa label-data text "Chrome")
#
# 73 (868-Chrome isa inc-label idata 868 label l-Chrome)
#
# 74 (l-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2 isa label-data text "xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2")
#
# 75 (868-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2 isa inc-label idata 868 label l-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2)
#
# 76 (l-- isa label-data text "-")
#
# 77 (868-- isa inc-label idata 868 label l--)
#
# 78 (l-xe6x8bxa1xe5xbcxb5 isa label-data text "xe6x8bxa1xe5xbcxb5")
#
# 79 (868-xe6x8bxa1xe5xbcxb5 isa inc-label idata 868 label l-xe6x8bxa1xe5xbcxb5)
#
# 80 (l-xe6xa9x9fxe8x83xbd isa label-data text "xe6xa9x9fxe8x83xbd")
#
# 81 (868-xe6xa9x9fxe8x83xbd isa inc-label idata 868 label l-xe6xa9x9fxe8x83xbd)
#
# 82 (l-Chrome isa label-data text "Chrome")
#
# 83 (869-Chrome isa inc-label idata 869 label l-Chrome)
#
# 84 (l-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2 isa label-data text "xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2")
#
# 85 (869-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2 isa inc-label idata 869 label l-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2)
#
# 86 (l-- isa label-data text "-")
#
# 87 (869-- isa inc-label idata 869 label l--)
#
# 88 (l-history isa label-data text "history")
#
# 89 (869-history isa inc-label idata 869 label l-history)
#
# 90 (l-export isa label-data text "export")
#
# 91 (869-export isa inc-label idata 869 label l-export)
#
# 92 (l-History isa label-data text "History")
#
# 93 (870-History isa inc-label idata 870 label l-History)
#
# 94 (l-export isa label-data text "export")
#
# 95 (870-export isa inc-label idata 870 label l-export)
#
# 96 (l-- isa label-data text "-")
#
# 97 (870-- isa inc-label idata 870 label l--)
#
# 98 (l-Chrome isa label-data text "Chrome")
#
# 99 (870-Chrome isa inc-label idata 870 label l-Chrome)
#
# 100 (l-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2 isa label-data text "xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2")
#
# 101 (870-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2 isa inc-label idata 870 label l-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2)
#
# 102 (l-Export isa label-data text "Export")
#
# 103 (871-Export isa inc-label idata 871 label l-Export)
#
# 104 (l-History isa label-data text "History")
#
# 105 (871-History isa inc-label idata 871 label l-History)
#
# 106 (l-/ isa label-data text "/")
#
# 107 (871-/ isa inc-label idata 871 label l-/)
#
# 108 (l-Bookmarks isa label-data text "Bookmarks")
#
# 109 (871-Bookmarks isa inc-label idata 871 label l-Bookmarks)
#
# 110 (l-to isa label-data text "to")
#
# 111 (871-to isa inc-label idata 871 label l-to)
#
# 112 (l-JSON isa label-data text "JSON")
#
# 113 (871-JSON isa inc-label idata 871 label l-JSON)
#
# 114 (l-/ isa label-data text "/")
#
# 115 (871-/ isa inc-label idata 871 label l-/)
#
# 116 (l-CSV isa label-data text "CSV")
#
# 117 (871-CSV isa inc-label idata 871 label l-CSV)
#
# 118 (l-*/ isa label-data text "*/")
#
# 119 (871-*/ isa inc-label idata 871 label l-*/)
#
# 120 (l-XLS isa label-data text "XLS")
#
# 121 (871-XLS isa inc-label idata 871 label l-XLS)
#
# 122 (l-* isa label-data text "*")
#
# 123 (871-* isa inc-label idata 871 label l-*)
#
# 124 (l-- isa label-data text "-")
#
# 125 (871-- isa inc-label idata 871 label l--)
#
# 126 (l-Chrome isa label-data text "Chrome")
#
# 127 (871-Chrome isa inc-label idata 871 label l-Chrome)
#
# 128 (l-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2 isa label-data text "xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2")
#
# 129 (871-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2 isa inc-label idata 871 label l-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2)
#
# 130 (l-json isa label-data text "json")
#
# 131 (872-json isa inc-label idata 872 label l-json)
#
# 132 (l-- isa label-data text "-")
#
# 133 (872-- isa inc-label idata 872 label l--)
#
# 134 (l-xls isa label-data text "xls")
#
# 135 (872-xls isa inc-label idata 872 label l-xls)
#
# 136 (l-com isa label-data text "com")
#
# 137 (872-com isa inc-label idata 872 label l-com)
#
# 138 (l-- isa label-data text "-")
#
# 139 (872-- isa inc-label idata 872 label l--)
#
# 140 (l-json isa label-data text "json")
#
# 141 (872-json isa inc-label idata 872 label l-json)
#
# 142 (l-/ isa label-data text "/")
#
# 143 (872-/ isa inc-label idata 872 label l-/)
#
# 144 (l-xml isa label-data text "xml")
#
# 145 (872-xml isa inc-label idata 872 label l-xml)
#
# 146 (l-to isa label-data text "to")
#
# 147 (872-to isa inc-label idata 872 label l-to)
#
# 148 (l-excel isa label-data text "excel")
#
# 149 (872-excel isa inc-label idata 872 label l-excel)
#
# 150 (l-/ isa label-data text "/")
#
# 151 (872-/ isa inc-label idata 872 label l-/)
#
# 152 (l-CSV isa label-data text "CSV")
#
# 153 (872-CSV isa inc-label idata 872 label l-CSV)
#
# 154 (l-/ isa label-data text "/")
#
# 155 (872-/ isa inc-label idata 872 label l-/)
#
# 156 (l-html isa label-data text "html")
#
# 157 (872-html isa inc-label idata 872 label l-html)
#
# 158 (l-online isa label-data text "online")
#
# 159 (872-online isa inc-label idata 872 label l-online)
#
# 160 (l-converter isa label-data text "converter")
#
# 161 (872-converter isa inc-label idata 872 label l-converter)
#
# 162 (l-and isa label-data text "and")
#
# 163 (872-and isa inc-label idata 872 label l-and)
#
# 164 (l-viewer isa label-data text "viewer")
#
# 165 (872-viewer isa inc-label idata 872 label l-viewer)
#
# 166 (l-History isa label-data text "History")
#
# 167 (873-History isa inc-label idata 873 label l-History)
#
# 168 (l-export isa label-data text "export")
#
# 169 (873-export isa inc-label idata 873 label l-export)
#
# 170 (l-- isa label-data text "-")
#
# 171 (873-- isa inc-label idata 873 label l--)
#
# 172 (l-Chrome isa label-data text "Chrome")
#
# 173 (873-Chrome isa inc-label idata 873 label l-Chrome)
#
# 174 (l-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2 isa label-data text "xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2")
#
# 175 (873-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2 isa inc-label idata 873 label l-xe3x82xa6xe3x82xa7xe3x83x96xe3x82xb9xe3x83x88xe3x82xa2)
#
# 176 (679-time4 isa time-data idata 679 time time4)
#
# 177 (864-time4 isa time-data idata 864 time time4)
#
# 178 (866-time4 isa time-data idata 866 time time4)
#
# 179 (867-time4 isa time-data idata 867 time time4)
#
# 180 (868-time4 isa time-data idata 868 time time4)
#
# 181 (869-time4 isa time-data idata 869 time time4)
#
# 182 (870-time4 isa time-data idata 870 time time4)
#
# 183 (871-time4 isa time-data idata 871 time time4)
#
# 184 (872-time4 isa time-data idata 872 time time4)
#
# 185 (873-time4 isa time-data idata 873 time time4)
#
# 186 ))
# 186

# %%
import json

json_open = open('history.json', 'r', encoding='utf8')
json_load = json.load(json_open)

time = 10**15
for i in range(9):
    time = min(json_load[i]['lastVisitTimeTimestamp'],time)
    if json_load[i]['id'] == '872':
        print(json_load[i])
time = int(time//1000)
print(time//1000)
# Out:
# {'typedCount': 0, 'url': 'http://www.json-xls.com/', 'lastVisitTimeTimestamp': 1587381226297.221, 'id': '872', 'lastVisitTime': '2020/4/20 20:13:46', 'visitCount': 1, 'title': 'json-xls.com - json/xml to excel/CSV/html online converter and viewer'}
# 1587378

# %%
#create image data
import glob
import os
files = glob.glob("./idata/*")

#(sdp 781 :creation-time 12313 :reference-list())

for file in files:
    with open(file ,mode="r", encoding='utf8') as f:
        with open("img-param.lisp",mode="w", encoding='utf8') as f2:
            s = ""
            tmp = 0
            for line in f.readlines():
                for text in line:
                    if text == '"':
                        tmp += 1
                        if tmp == 1:
                            continue
                    if tmp == 1:
                        s += text
                    elif tmp == 2:
                        break
                f2.write('(sdp '+s+' :creation-time '+str(time)+' :reference-count '+leng+')\n')
                break
        print(file)
# Out:
# ./idata\679.lisp
# ./idata\864.lisp
# ./idata\866.lisp
# ./idata\867.lisp
# ./idata\868.lisp
# ./idata\869.lisp
# ./idata\870.lisp
# ./idata\871.lisp
# ./idata\872.lisp
# ./idata\873.lisp

# %%
#create label data
import glob
import os
files = glob.glob("./idata/*")
#(sdp 781-Chrome :creation-time 12313 :reference-list())
#(sdp l-headgear :creation-time 1580985649 :reference-list (1580985649))
for file in files:
    with open(file ,mode="r", encoding='utf8') as f:
        with open("img-param.lisp",mode="a", encoding='utf8') as f2:
            ls = []
            for line in f.readlines():
                s = ""
                tmp = 0
                for i in range(len(line)):
                    if line[i] == '"':
                        tmp += 1
                        if tmp == 1:
                            continue
                    if tmp == 2:
                        break
                    elif tmp == 1:
                        s += str(line[i])
                if s == "":
                    break
                ls.append(s)
                if ls[0] == s:
                    continue
                f2.write('(sdp '+str(ls[0])+"-"+s+" :creation-time "+str(time)+' :reference-count '+leng+')\n')
                f2.write('(sdp '+"l-"+s+" :creation-time "+str(time)+' :reference-count '+leng+')\n')
        print(file)
# Out:
# ./idata\679.lisp
# ./idata\864.lisp
# ./idata\866.lisp
# ./idata\867.lisp
# ./idata\868.lisp
# ./idata\869.lisp
# ./idata\870.lisp
# ./idata\871.lisp
# ./idata\872.lisp
# ./idata\873.lisp

# %%
#create time data
import glob
import os
import json
files = glob.glob("./idata/*")
json_open = open('history.json', 'r', encoding='utf8')
json_load = json.load(json_open)

def time_classify(time):
    if time[5] == '4':
        return 'time4'
    elif time[5] == '3':
        return 'time3'
    elif time[5] == '2':
        return 'time2'

for file in files:
    with open(file ,mode="r", encoding='utf8') as f:
        with open("img-param.lisp",mode="a", encoding='utf8') as f2:
            s = ""
            tmp = 0
            for line in f.readlines():
                for text in line:
                    if text == '"':
                        tmp += 1
                        if tmp == 1:
                            continue
                    if tmp == 1:
                        s += text
                    elif tmp == 2:
                        break
                for i in range(len(json_load)):
                    if json_load[i]['id'] == s:
                        times = time_classify(json_load[i]['lastVisitTime'])
                        print(time)
                        f2.write('(sdp '+s+'-'+times+' :creation-time '+str(time)+' :reference-count '+leng+')\n')
                        break
                break
        print(file)
        
#(sdp 781-time2 :creation-time 12313 :reference-list())
# Out:
# 1587378035
# ./idata\679.lisp
# 1587378035
# ./idata\864.lisp
# 1587378035
# ./idata\866.lisp
# 1587378035
# ./idata\867.lisp
# 1587378035
# ./idata\868.lisp
# 1587378035
# ./idata\869.lisp
# 1587378035
# ./idata\870.lisp
# 1587378035
# ./idata\871.lisp
# 1587378035
# ./idata\872.lisp
# 1587378035
# ./idata\873.lisp

# %%
with open('img-param.lisp',mode='r',encoding='utf8') as f:
    ls = []
    for i in f.readlines():
        ls.append(i)
print(len(ls))
ls = set(ls)
print(len(ls))
with open('img-param.lisp', mode='w', encoding='utf8') as f:
    for i in ls:
        f.write(i)
# Out:
# 89
# 84
